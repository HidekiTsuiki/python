# %% [markdown]
# 練習問題5
#
# (2**(2**(2**2)) が 65536 なので，2 の 65536 乗です。2 の 10 乗がほぼ 10 の 3 乗なので，
# $$
# 2^{65536} = (2^{10})^{6553} \times 2^6 \sim  {(10^3)} ^ {6553} \times 64 $$
# なので，3 * 6554 + 1 桁ほどの桁数があります。これは，10 進法で書くと横幅 80 文字，行数 80で，3 ページ分です。

# %%
#練習問題10
n = 10
#n = 100

# %%
#練習問題10
print((1 + 1/n)**n)
# Out:
# 2.5937424601000023

# %%
#練習問題15
a = 2.5
x = 0.01

# %%
#練習問題15
x = a * x * (1-x)
print(x)
# Out:
# 0.5999999999971676

# %%
# 練習問題 30
n = 1

# %%
# 練習問題 30
print("n=", n, ", e=", (1+1/n)**n)
n = n + 1
# Out:
# n= 10 , e= 2.5937424601000023

# %%
#練習問題 40
n = 0
sum = 0

# %%
#練習問題 40
sum = sum + (2*n+1)
print("n=", n , ", sum=", sum)
n = n + 1
# Out:
# n= 9 , sum= 100

# %% [markdown]
# **練習問題50** 下の，テキストの作成のところまで勉強した後に，その推測の証明を，このセルの中の...に数式をうめて完成させよう。
#
# $$\sum_{i=0}^{n}{i}= \frac{n(n+1)}{2}$$
# である。よって，
# $$\sum_{i=0}^{n}{(2i+1)}=
# 2\sum_{i=0}^{n}{i} +
# \sum_{i=0}^{n}{1}= n(n+1) + (n+1) = (n+1)^2
# $$

# %%
#練習問題60
n = 1
sum = 1
fact = 1

# %%
fact = fact * n
sum = sum + 1/fact
n = n + 1
print(n, sum)
# Out:
# 20 2.7182818284590455

# %%
# 答えは一つではないです。
# いろんな書き方が考えられます。


sum = 0
n = 0

# %%
sum = sum + ((-1)**n)/(2 * n + 1 )
print(n, sum*4)
n = n + 1
# Out:
# 63 3.125968606973288

# %%
# 練習問題8

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, np.pi*2*10, 100) 

plt.plot(x, np.sin(x))
plt.show()

# %%
# 練習問題8

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, np.pi*2*10, 1000) 

plt.plot(x, np.sin(x))
plt.show()
