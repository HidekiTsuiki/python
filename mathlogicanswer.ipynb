# %%
minus = [[2,1,1,2],
 [1,0,0],
 [2,2,3,4],
 [2,0,2,4],
 [0]
]  
minusm = listnum(list(map(listnum, minus)))

# %%
univm(minusm, listnum([0,2,0]))
# Out:
# 0 [0, 2, 0]
# 1 [0, 1, 0]
# 0 [1, 1, 0]
# 1 [1, 0, 0]
# 0 [2, 0, 0]
# 2 [2, 0, 0]
# 2

# %%
mult = [[2,2,1,6],
        [2,1,2,4],
        [1,0,3],
        [1,3,1],
        [2,3,5,0],
        [1,1,4],
        [0]]
multm = listnum(list(map(listnum,mult)))

# %%
multm
# Out:
# 3569087915628215273157872119327898774307983130029894843074285382414903659146724955082665477956549619642759345309113910178254286567503605094753306574605740101228890706563522535903228049352267494654792579423561756558

# %%
univm(multm, listnum([0,4,8]))
# Out:
# 0 [0, 4, 8]
# 1 [0, 4, 7]
# 2 [0, 3, 7]
# 3 [1, 3, 7]
# 1 [1, 3, 7, 1]
# 2 [1, 2, 7, 1]
# 3 [2, 2, 7, 1]
# 1 [2, 2, 7, 2]
# 2 [2, 1, 7, 2]
# 3 [3, 1, 7, 2]
# 1 [3, 1, 7, 3]
# 2 [3, 0, 7, 3]
# 3 [4, 0, 7, 3]
# 1 [4, 0, 7, 4]
# 4 [4, 0, 7, 4]
# 5 [4, 0, 7, 3]
# 4 [4, 1, 7, 3]
# 5 [4, 1, 7, 2]
# 4 [4, 2, 7, 2]
# 5 [4, 2, 7, 1]
# 4 [4, 3, 7, 1]
# 5 [4, 3, 7, 0]
# 4 [4, 4, 7, 0]
# 0 [4, 4, 7, 0]
# 1 [4, 4, 6, 0]
# 2 [4, 3, 6, 0]
# 3 [5, 3, 6, 0]
# 1 [5, 3, 6, 1]
# 2 [5, 2, 6, 1]
# 3 [6, 2, 6, 1]
# 1 [6, 2, 6, 2]
# 2 [6, 1, 6, 2]
# 3 [7, 1, 6, 2]
# 1 [7, 1, 6, 3]
# 2 [7, 0, 6, 3]
# 3 [8, 0, 6, 3]
# 1 [8, 0, 6, 4]
# 4 [8, 0, 6, 4]
# 5 [8, 0, 6, 3]
# 4 [8, 1, 6, 3]
# 5 [8, 1, 6, 2]
# 4 [8, 2, 6, 2]
# 5 [8, 2, 6, 1]
# 4 [8, 3, 6, 1]
# 5 [8, 3, 6, 0]
# 4 [8, 4, 6, 0]
# 0 [8, 4, 6, 0]
# 1 [8, 4, 5, 0]
# 2 [8, 3, 5, 0]
# 3 [9, 3, 5, 0]
# 1 [9, 3, 5, 1]
# 2 [9, 2, 5, 1]
# 3 [10, 2, 5, 1]
# 1 [10, 2, 5, 2]
# 2 [10, 1, 5, 2]
# 3 [11, 1, 5, 2]
# 1 [11, 1, 5, 3]
# 2 [11, 0, 5, 3]
# 3 [12, 0, 5, 3]
# ...
